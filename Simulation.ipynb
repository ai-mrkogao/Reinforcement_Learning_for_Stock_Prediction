# %%
# %run train ^GSPC 10 10
# Out:
# Episode 0/10
# Buy: $1347.56
# Sell: $1333.34 | Profit: -$14.22
# Buy: $1298.35
# Buy: $1300.80
# Buy: $1313.27
# Sell: $1326.82 | Profit: $28.47
# Sell: $1318.55 | Profit: $17.75
# Sell: $1329.47 | Profit: $16.20
# Buy: $1342.90
# Sell: $1360.40 | Profit: $17.50
# Buy: $1364.17
# Buy: $1354.31
# Sell: $1340.89 | Profit: -$23.28
# Buy: $1314.76
# Sell: $1318.80 | Profit: -$35.51
# Buy: $1326.61
# Buy: $1301.53
# Buy: $1278.94
# Sell: $1255.27 | Profit: -$59.49
# Sell: $1245.86 | Profit: -$80.75
# Buy: $1257.94
# Sell: $1239.94 | Profit: -$61.59
# Sell: $1241.23 | Profit: -$37.71
# Sell: $1241.41 | Profit: -$16.53
# Buy: $1253.80
# Sell: $1261.89 | Profit: $8.09
# Buy: $1233.42
# Buy: $1180.16
# Buy: $1173.56
# Sell: $1150.53 | Profit: -$82.89
# Buy: $1170.81
# Sell: $1142.62 | Profit: -$37.54
# Sell: $1152.69 | Profit: -$20.87
# Buy: $1182.17
# Sell: $1153.29 | Profit: -$17.52
# Buy: $1160.33
# Buy: $1145.87
# Sell: $1106.46 | Profit: -$75.71
# Sell: $1103.25 | Profit: -$57.08
# ...

# %%
# %run evaluate.py ^GSPC_2011 model_ep0
# Out:
# --------------------------------
# ^GSPC_2011 Total Profit: $0.00
# --------------------------------
